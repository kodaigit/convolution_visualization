# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def func_f(low, high,input,output): 
    if (input < low) or (input > high):
        return 0 
    else:
        return output

def func_h(low, high,input,output): 
    if (input < low) or (input > high):
        return 0 
    else:
        return output

# %%
plt.plot(func_f(-1,1,1000))
